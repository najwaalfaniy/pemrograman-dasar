# %%
#Biodata Saya

nama = "Najwa "
umur = 21
jurusan = "Elektro"
prodi = "TRPE"
semester = 3
matakuliah = 'Pemrograman Dasar'
status_lulus = False

#perintah untuk menampilkan nilai pada variabel

print (nama)
print (umur)
print (jurusan)
print (prodi)
print (semester)
print (matakuliah)
print (status_lulus)
# Out:
# Najwa
# 21
# Elektro
# TRPE
# 3
# Pemrograman Dasar
# False
