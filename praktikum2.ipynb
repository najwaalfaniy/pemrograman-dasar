# %% [markdown]
# <a href="https://colab.research.google.com/github/najwaalfaniy/pemrograman-dasar/blob/main/praktikum2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Kode Percobaan

# %%
# Program pertama Anda
print("Halo, Python! — Praktikum TRPE")

# Contoh: data sebuah panel surya
tegangan = 220          # int
arus = 5.5              # float
nama_alat = "Inverter"  # str
aktif = True            # bool

print(tegangan, arus, nama_alat, aktif)

# Melihat daftar kata kunci yang TIDAK boleh dipakai sebagai nama variabel
import keyword
print(keyword.kwlist)

# Beberapa nilai sekaligus & tukar nilai (swap)
v1, v2, v3 = 12, 24, 48
print(v1, v2, v3)

# Menukar tanpa variabel bantu — ciri khas Python
a, b = 10, 20
a, b = b, a
print("Setelah swap:", a, b)

# Deklarasi tipe primitif dengan konteks kelistrikan
frekuensi = 50                 # int  — Hz
faktor_daya = 0.85             # float — cos φ
tiga_fasa = True               # bool
label = "Trafo Distribusi"     # str
impedansi = complex(4, 3)      # complex — Z = R + jX (Ohm)

# Fungsi type() untuk memeriksa tipe data
print(type(frekuensi))
print(type(faktor_daya))
print(type(tiga_fasa))
print(type(label))
print(type(impedansi))

# LIST — data pembacaan suhu generator (bisa diubah, ada indeks)
suhu_harian = [68.5, 70.1, 71.3, 69.8, 72.0]
print("Suhu jam ke-3:", suhu_harian[2])   # indeks mulai dari 0
suhu_harian.append(73.2)                   # menambah data
print("Setelah ditambah:", suhu_harian)

# TUPLE — spesifikasi tetap yang tidak boleh berubah
rating_trafo = (220, 380, 50)   # (V primer, V sekunder, frekuensi)
print("Tegangan primer:", rating_trafo[0])

# SET — daftar jenis pembangkit unik (duplikat otomatis dibuang)
jenis_pembangkit = {"PLTU", "PLTA", "PLTS", "PLTU"}
print("Jenis unik:", jenis_pembangkit)

# DICT — spesifikasi satu unit pembangkit (akses lewat key)
generator = {
    "nama": "Unit-1",
    "kapasitas_MW": 100,
    "tegangan_kV": 11,
    "status": "operasi"
}
print("Kapasitas:", generator["kapasitas_MW"], "MW")
generator["status"] = "pemeliharaan"   # mengubah nilai
print(generator)
# Out:
# Halo, Python! — Praktikum TRPE
# 220 5.5 Inverter True
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 12 24 48
# Setelah swap: 20 10
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>
# <class 'complex'>
# Suhu jam ke-3: 71.3
# Setelah ditambah: [68.5, 70.1, 71.3, 69.8, 72.0, 73.2]
# Tegangan primer: 220
# Jenis unik: {'PLTU', 'PLTS', 'PLTA'}
# Kapasitas: 100 MW
# {'nama': 'Unit-1', 'kapasitas_MW': 100, 'tegangan_kV': 11, 'status': 'pemeliharaan'}

# %% [markdown]
# Sel Demo

# %%
# print() dengan beberapa argumen sekaligus
print("Tegangan:", 220, "Volt")

# type() untuk mengecek tipe
print(type(220))        # <class 'int'>
print(type("PLTU"))     # <class 'str'>

# len() menghitung jumlah elemen dan panjang teks
komponen = ["resistor", "kapasitor", "dioda"]
print(len(komponen))    # 3
print(len("Trafo"))     # 5

# complex() membuat bilangan kompleks
print(complex(4, 3))    # (4+3j)

# .append() method milik list
komponen.append("transistor")
print(komponen)         # bertambah 'transistor' di akhir
# Out:
# Tegangan: 220 Volt
# <class 'int'>
# <class 'str'>
# 3
# 5
# (4+3j)
# ['resistor', 'kapasitor', 'dioda', 'transistor']

# %% [markdown]
# Latihan 1 — Membuat variabel (mudah)
# Sebuah panel surya memiliki tegangan 18 volt, arus 6 ampere, dan jenis sel "Monocrystalline". Buat tiga variabel dengan nama yang sesuai konvensi PEP 8, lalu cetak ketiganya.

# %%
tegangan = 18
arus = 6
jenis_sel = "Monocrystalline"

print("tegangan panel surya", (tegangan), "volt")
print("arus", (arus), "ampere")
print("jenis sel", (jenis_sel))
# Out:
# tegangan panel surya 18 volt
# arus 6 ampere
# jenis sel Monocrystalline

# %% [markdown]
# Latihan 2 — Tipe primitif & type() (mudah)
# Buat satu variabel untuk masing-masing tipe: int, float, bool, str (data komponen elektronika bebas). Cetak nilai dan tipe tiap variabel dengan type().

# %%
tegangan = 12
resistansi = 10.5
aktif = True
komponen = "Resistor"

print(tegangan, type(tegangan))
print(resistansi, type(resistansi))
print(aktif, type(aktif))
print(komponen, type(komponen))
# Out:
# 12 <class 'int'>
# 10.5 <class 'float'>
# True <class 'bool'>
# Resistor <class 'str'>

# %% [markdown]
# Latihan 3 — Memilih tipe yang tepat (sedang)
# Tentukan tipe data yang paling sesuai untuk tiap data berikut, buat variabelnya, lalu buktikan dengan type():
#
# Nama unit: PLTS Nunukan
# Jumlah panel: 240
# Tegangan keluaran: 48.5
# Sedang beroperasi: benar

# %%
nama_unit = "PLTS Nunukan"
jumlah_panel = 240
tegangan_keluaran = 48.5
sedang_beroperasi = True

print(nama_unit, type(nama_unit))
print(jumlah_panel, type(jumlah_panel))
print(tegangan_keluaran, type(tegangan_keluaran))
print(sedang_beroperasi, type(sedang_beroperasi))
# Out:
# PLTS Nunukan <class 'str'>
# 240 <class 'int'>
# 48.5 <class 'float'>
# True <class 'bool'>

# %% [markdown]
# Latihan 4 — List (sedang)
# Berikut daftar pembacaan tegangan (V) sebuah panel:
#
# tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]
# Tugas: (a) cetak pembacaan pertama dan terakhir memakai indeks, (b) tambahkan satu pembacaan baru 222.0 dengan append(), (c) cetak jumlah total data dengan len().

# %%
tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]

# (a) Pembacaan pertama dan terakhir
print("tegangan harian pertama:", (tegangan_harian[0]) , "tegangan harian terakhir:", (tegangan_harian[5]))

# (b) Tambahkan pembacaan baru
tegangan_harian.append(222.0)
print("tegangan harian:", (tegangan_harian))

# (c) Jumlah total data
print("total data:", len(tegangan_harian))
# Out:
# tegangan harian pertama: 217.5 tegangan harian terakhir: 216.9
# tegangan harian: [217.5, 219.0, 220.3, 218.7, 221.1, 216.9, 222.0]
# total data: 7

# %% [markdown]
# Latihan 5 — Dictionary (sedang)
# Buat dictionary spesifikasi sebuah motor listrik (minimal: nama, daya_kW, tegangan_V, rpm). Cetak salah satu nilai lewat key-nya, lalu ubah nilai rpm (pakai =), dan cetak ulang seluruh dictionary.

# %%
motor = {
    "nama" : "Motor Induksi",
    "daya_kW": 5.5,
    "tegangan_V": 400,
    "rpm": 1500
}

# Cetak salah satu nilai melalui key
print("nama:", (motor["nama"]))

# Ubah nilai rpm
motor["rpm"] = 1450

# Cetak seluruh dictionary
print(motor)
print("nama:", motor["nama"])
print("daya:", motor["daya_kW"], "kW")
print("tegangan:",motor["tegangan_V"], "V")
print("rpm:", motor["rpm"])
# Out:
# nama: Motor Induksi
# {'nama': 'Motor Induksi', 'daya_kW': 5.5, 'tegangan_V': 400, 'rpm': 1450}
# nama: Motor Induksi
# daya: 5.5 kW
# tegangan: 400 V
# rpm: 1450

# %% [markdown]
# Latihan 6 — Gabungan (menantang)
# Kelola data tiga unit pembangkit sebagai list of dictionary, tiap unit berisi nama, kapasitas_MW, dan status. Tugas: cetak nama unit kedua, ubah status salah satu unit, tambahkan satu unit baru ke list dengan append(), lalu cetak seluruh data.
#
# # Jawaban Latihan 6
# pembangkit = [
#     {"nama": "Unit-1", "kapasitas_MW": 100, "status": "operasi"},
#     {"nama": "Unit-2", "kapasitas_MW": 150, "status": "operasi"},
#     {"nama": "Unit-3", "kapasitas_MW": 80,  "status": "pemeliharaan"},
# ]

# %%
pembangkit = [
    {
        "nama": "Unit-1",
        "kapasitas_MW": 100,
        "status": "Beroperasi"
    },
    {
        "nama": "Unit-2",
        "kapasitas_MW": 150,
        "status": "Beroperasi"
    },
    {
        "nama": "Unit-3",
        "kapasitas_MW": 80,
        "status": "Pemeliharaan"
    }
]

# Cetak nama unit kedua
print(pembangkit[1]["nama"])

# Ubah status salah satu unit
pembangkit[2]["status"] = "Beroperasi"

# Tambahkan satu unit baru
pembangkit.append({
    "nama": "Unit-4",
    "kapasitas_MW": 200,
    "status": "Perencanaan"
})

# Cetak seluruh data
print(pembangkit)
print("nama:", pembangkit[0]["nama"])
print("kapasitas:", pembangkit[0]["kapasitas_MW"], "MW")
print("status:", pembangkit[0]["status"])

print("nama:", pembangkit[1]["nama"])
print("kapasitas:", pembangkit[1]["kapasitas_MW"], "MW")
print("status:", pembangkit[1]["status"])

print("nama:", pembangkit[2]["nama"])
print("kapasitas:", pembangkit[2]["kapasitas_MW"], "MW")
print("status:", pembangkit[2]["status"])

print("nama:", pembangkit[3]["nama"])
print("kapasitas:", pembangkit[3]["kapasitas_MW"], "MW")
print("status:", pembangkit[3]["status"])
# Out:
# Unit-2
# [{'nama': 'Unit-1', 'kapasitas_MW': 100, 'status': 'Beroperasi'}, {'nama': 'Unit-2', 'kapasitas_MW': 150, 'status': 'Beroperasi'}, {'nama': 'Unit-3', 'kapasitas_MW': 80, 'status': 'Beroperasi'}, {'nama': 'Unit-4', 'kapasitas_MW': 200, 'status': 'Perencanaan'}]
# nama: Unit-1
# kapasitas: 100 MW
# status: Beroperasi
# nama: Unit-2
# kapasitas: 150 MW
# status: Beroperasi
# nama: Unit-3
# kapasitas: 80 MW
# status: Beroperasi
# nama: Unit-4
# kapasitas: 200 MW
# status: Perencanaan
